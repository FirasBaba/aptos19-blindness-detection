# %%
import os
import time
import copy
import torch
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import argparse
from collections import defaultdict, Counter
import random

import pandas as pd
from tqdm import tqdm

# %%
old_data = pd.read_csv("../input/2015_data/trainLabels.csv")
old_data.columns=["id_code","diagnosis"]

# %%
new_data = pd.read_csv("../input/train.csv")

# %%
def make_folds(df, n_folds=5):
    df['diagnosis']=df['diagnosis'].astype("str")
    cls_counts = Counter(cls for classes in df['diagnosis'].str.split()
                         for cls in classes)
    fold_cls_counts = defaultdict(int)
    folds = [-1] * len(df)
    for item in tqdm(df.sample(frac=1, random_state=42).itertuples(),
                          total=len(df)):
        cls = min(item.diagnosis.split(), key=lambda cls: cls_counts[cls])
        fold_counts = [(f, fold_cls_counts[f, cls]) for f in range(n_folds)]
        min_count = min([count for _, count in fold_counts])
        random.seed(item.Index)
        fold = random.choice([f for f, count in fold_counts
                              if count == min_count])
        folds[item.Index] = fold
        for cls in item.diagnosis.split():
            fold_cls_counts[fold, cls] += 1
    df['fold'] = folds
    return df

# %%
df_old = make_folds(pd.concat([old_data]), n_folds=10)
# Out:
# 100%|██████████| 35126/35126 [00:00<00:00, 73482.18it/s]

# %%
old_data.shape
# Out:
# (35126, 2)

# %%
df_old = df_old[df_old.fold==1].reset_index(drop=True)[["id_code","diagnosis"]]

# %%
df_final = pd.concat([new_data,df_old]).reset_index(drop=True)

# %%
df = make_folds(df_final, n_folds=5)
# Out:
# 100%|██████████| 7174/7174 [00:00<00:00, 84321.68it/s]

# %%
df.to_csv("../input/new_folds.csv",index=False)

# %%
df
# Out:
#            id_code diagnosis  fold
# 0     000c1434d8d7         2     4
# 1     001639a390f0         4     0
# 2     0024cdab0c1e         1     2
# 3     002c21358ce6         0     2
# 4     005b95c28852         0     1
# 5     0083ee8054ee         4     4
# 6     0097f532ac9f         0     4
# 7     00a8624548a9         2     3
# 8     00b74780d31d         2     0
# 9     00cb6555d108         1     4
# 10    00cc2b75cddd         0     0
# 11    00e4ddff966a         2     3
# 12    00f6c1be5a33         0     3
# 13    0104b032c141         3     3
# 14    0124dffecf29         1     0
# 15    0125fbd2e791         0     1
# 16    012a242ac6ff         2     2
# 17    014508ccb9cb         0     4
# 18    0151781fe50b         0     2
# 19    0161338f53cc         2     3
# 20    0180bfa26c0b         2     3
# 21    0182152c50de         0     1
# 22    01b3aed3ed4c         1     0
# 23    01c7808d901d         2     3
# 24    01d9477b1171         0     0
# 25    01eb826f6467         2     4
# ...
